# %% [markdown]
# <a href="https://colab.research.google.com/github/JoshStrother/DataVisualization/blob/main/Lesson23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Josh Strother**

# %% [markdown]
# The first graph is a simple one from
#
# https://www.statista.com/statistics/220739/forecast-of-dvd-player-shipments-in-the-us/
#
# This chart shows quarterly tv sales in the United States from 2012-2017.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# It looks like there are an even number of sales through-out the whole year up until the 4th quarter every year and the sales sky rocket.  Since this is a US graph, we can assume that it’s because of Christmas that the sales do this.  The quarters are labeled well, the bars tell you pretty exactly how many sales there were each quarter and you don’t have to take a wild guess because the axis is numbered and the numbers on the individual bars.  Could this graph be more sophisticated in the way that is has more to the graphics rather than just simple bars? Sure.  But it is very telling of the data just the way it is now.

# %% [markdown]
# -----------------------------------------------------------------------------------------------

# %% [markdown]
# The second graphic is from
#
# https://aperiodical.com/2017/03/not-a-pizza-pie-chart/
#
# it shows percent of people from a survey that like each topping on a pizza.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# First off, I really love the idea of showing real pizza and toppings to discuss the percentage.  However, there are several big issues with this.  The first problem is that they are using a pie chart to show the percentage of people that like something where there can be more than one answer per person rather than a single value such as the sales.  Another big problem is that the pizza is misleading.  There are large precents on the bottom in grey such as 62% like onions and 56% like chicken.  This makes it look some odd toppings are really popular and some common ones are nowhere to be found.  This is a well-made graphic, it is just not utilized correctly.
