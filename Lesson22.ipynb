# %% [markdown]
# <a href="https://colab.research.google.com/github/JoshStrother/DataVisualization/blob/main/Lesson22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The Power of Successful Onboarding for New Employees
#
# https://symposium.foragerone.com/okrd22/presentations/37165
#
# The following graph explains what percentage of information given to you on the first day of a job is valuable.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Reading the information from the poster this is valid data.  It is presented in a decent format and the slice sizes portay the acutal value decently.  But the issue with 3D pie charts is the side furthest from you looks smaller.  So maybe this chart might be very slightly biased towards information being more valuable.  But that isn't necessarily a bad thing because you probably should be paying attention to instructions given to you.

# %% [markdown]
# --------------------------------------------------------------------------------------

# %% [markdown]
# Evaluating the Different uses of Facebook Posts for a Family-Owned Business and a Corporately Owned Business
#
# https://symposium.foragerone.com/okrd22/presentations/37212
#
# The following bar charts show the number of likes each month for 2 different pop-corn businesses.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *I read through the poster quickly and couldn't tell if this is percentage of followers that like the post or how exactly these percentages work but I believe it to be likes per post to follower ratio.
# *So for both we can see there are values and there are dates for when these events occured.  The bars a proportional for each chart, but comparing the Mom & Pop to Garrett we can see that .54% is the same height at 2.36%.  Now maybe Garrett has more followers than Mom & Pop and so his .54% of followers liking is equivalent to M&P's 2.36%.
# *The graphs are good except for that and the fact that 2% is not a lot of your followers giving you posts attention.  So maybe the bar being full at 2.36% isnt very ideal.

# %% [markdown]
# -----------------------------------------------------------------------------

# %% [markdown]
# Evaluating Sports Media
#
# https://symposium.foragerone.com/okrd22/presentations/37205
#
# The following graphs just show social media follows and the bottom right shows likes.  The big grey one we will call 1, the Division I we will call 2 and the bottom right we will call 3.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *So #1 is a pretty good chart.  Reads well and tells exactly what is what. Values are proportional and data is easily read.  The only issue I see is that the actual number could be on the bars just for a more exact reading, would also help us see if maybe one of the bars was lying to us.
#
# *#2 is an okay chart.  Not much that can go in to it honestly, but i think the states IG follower count could be more apparent as discussed for #1 but atleast it isn't showing up something similar to the tax cut graph that shows that little percent being a huge mark up.
#
# *#3 Another decent graph, this one actually does tell you how many likes exactly on each, but there is no scale on the y-axis.  The bars do seem to be proportionate though.

# %% [markdown]
# ------------------------------------------------------------------------

# %% [markdown]
# ***Honorable Mention***
#
# A Longitudinal Analysis of Gender Disparities in the National Cancer Institute Study Section A
#
# https://symposium.foragerone.com/okrd22/presentations/37211
#
# The graph below shows number of each sex on a panel.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This graph was very useful and presented information well.  I couldn't just not include it because it shows everything we need and has a description with it as well.
